# %% [markdown]
# 1. What are escape characters, and how do you use them?
#
# Ans: An escape character is a backslash \ followed by the character you want to insert. This is used to insert something in a string.
#
# a = " This is a "cool" sentence" (if we print this statement the we will get syntax error)
#
# a = " This is a \"cool"\ sentence" (if we print this statement the we will get the word cool in the output)

# %%
print(" This is a "cool" sentence")
# Out:
#   File "<ipython-input-1-b51800f019be>", line 1
#     print(" This is a "cool" sentence")
#                        ^
# SyntaxError: invalid syntax

# %%
print(" This is a \"cool\" sentence")
# Out:
#  This is a "cool" sentence

# %% [markdown]
# 2. What do the escape characters n and t stand for?
#
# Ans: \n means new line. \t means tab

# %% [markdown]
# 3. What is the way to include backslash characters in a string?
#
# Ans: by using escape characters.

# %%
print(" This is a \"cool\" sentence")
# Out:
#  This is a "cool" sentence

# %% [markdown]
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?
#
# Ans: Howl's has not escaped a problem because the sentence in double quotes. " "

# %% [markdown]
# 5. How do you write a string of newlines if you don't want to use the n character?
#
# Ans: We can use end=" ".
#
# We can write separate strings in different line.

# %% [markdown]
# 6. What are the values of the given expressions?
# 'Hello, world!'[1]
# 'Hello, world!'[0:5]
# 'Hello, world!'[:5]
# 'Hello, world!'[3:]

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# 7. What are the values of the following expressions?
# 'Hello'.upper()
# 'Hello'.upper().isupper()
# 'Hello'.upper().lower()

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# 8. What are the values of the following expressions?
# 'Remember, remember, the fifth of July.'.split()
# '-'.join('There can only one.'.split())

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# 9. What are the methods for right-justifying, left-justifying, and centering a string?
#
# right-justifying : str.rjust()
#
# left-justifying  : str.ljust()
#
# centering : str.center()

# %% [markdown]
# 10. What is the best way to remove whitespace characters from the start or end?
#
# Ans: txt.strip() removes whitespace characters from the start or end
